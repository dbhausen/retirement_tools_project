# %%
def printall(*args,otherkeyword='June',**kwargs):
   
   for arg in args:
      print('arg:',arg)
      
   print(otherkeyword)  
   
   no_order = 0
   
   for k in kwargs:
      no_order += 5 
      print(no_order)
      print ('kwarg:',k, '=', kwargs[k])
      


   print(*args,kwargs)
   # print(p1)
   print(otherkeyword)
   print(kwargs['thirdkewword'])
   print(kwargs['fish'],*args)
   
printall('pete','fred','tom',fish='bill',otherkeyword='Mary',thirdkewword='h')  
printall('pete','fred','tom',fish='bill',thirdkewword='h')  
printall('pete','fred','tom',fish='bill')
# Out:
# arg: pete
# arg: fred
# arg: tom
# Mary
# 5
# kwarg: fish = bill
# 10
# kwarg: thirdkewword = h
# pete fred tom {'fish': 'bill', 'thirdkewword': 'h'}
# Mary
# h
# bill pete fred tom
# arg: pete
# arg: fred
# arg: tom
# June
# 5
# kwarg: fish = bill
# 10
# kwarg: thirdkewword = h
# pete fred tom {'fish': 'bill', 'thirdkewword': 'h'}
# June
# h
# bill pete fred tom
# arg: pete
# arg: fred
# arg: tom
# June
# 5
# kwarg: fish = bill
# pete fred tom {'fish': 'bill'}
# June
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\david\P2\retirement_tools_project\A_SITE\jupyter_scripts\dict.ipynb Cell 2 in <module>
#      <a href='vscode-notebook-cell:/c%3A/Users/david/P2/retirement_tools_project/A_SITE/jupyter_scripts/dict.ipynb#W1sZmlsZQ%3D%3D?line=22'>23</a> printall('pete','fred','tom',fish='bill',otherkeyword='Mary',thirdkewword='h')
# ...

# %%
class Adam: 
   myName = 'Adam'
class Eve:
   def __init__(self):
      print(self)
      print('My name was Eve!!!')
   def sayHello(self):
      print('hello' , self.__class__)  
   
class Glen(Adam,Eve): 
   myName='Glen'
   def __init__(self):
      print('My name was Glen.')
      super().__init__()
class Lorain(Eve,Adam):
   myName='Lorain'
class David(Adam,Eve):
   myName = 'David'
   def __init__(self):
      print(super().myName)
      super().__init__()

class Chemist: pass      

class Craig(Chemist,David):pass
   

# help(David)
# d=David()
# print(David.myName)
c=Craig()
c.sayHello()

help(Craig)
# Out:
# Adam
# ...
# My name was Eve!!!
# hello <class '__main__.Craig'>
# Help on class Craig in module __main__:
#
# class Craig(Chemist, David)
#  |  Method resolution order:
#  |      Craig
#  |      Chemist
#  |      David
#  |      Adam
#  |      Eve
#  |      builtins.object
#  |
#  |  Data descriptors inherited from Chemist:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from David:
#  |
#  |  __init__(self)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from David:
#  |
#  |  myName = 'David'
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from Eve:
#  |
# ...
